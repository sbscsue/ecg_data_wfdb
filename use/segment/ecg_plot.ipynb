# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 


from os.path import abspath
from os import listdir
import sys

home_path = "C:\\sebin\\lab\\ecg"
git_path = home_path+"\\ecg_data_wfdb"
sys.path.append(git_path)

from use.segment.open import ecgtodf

# %%
output_folder = abspath(home_path+"\\save\\mit_ann_all\\type2")

# %%
while(True):
    ann = str(input())
    if ann=='.':
        break
    else:
        folder = listdir("C:\\sebin\\lab\\ecg\\save\\mit_ann_all\\type2")
        if ann in folder:
            index = -1
            folder = output_folder+"\\"+ann
            files = listdir(folder)

            n = len(folder)

            while(True):
                check = str(input())
                if check == 'N':
                    if index < n-1:
                        index+=1

                        file = folder+"\\"+files[index]
                        print(file)

                        ecg = pd.read_csv(file,header=None)
                        ecg = ecg[0:-1].to_numpy()
                        ecg = ecg.astype('float')
                        plt.plot(ecg)
                        plt.show()

                    else:
                        print("인덱스가 끝에 있습니다.")
                        break
                if check == 'P':
                    if index > 0:
                        index-=1

                        file = folder+"\\"+files[index]
                        print(file)

                        ecg = pd.read_csv(file,header=None)
                        ecg = ecg[0:-1].to_numpy()
                        ecg = ecg.astype('float')
                        plt.plot(ecg)
                        plt.show()
                    else:
                        print("인덱스가 앞에 있습니다.")
                        break
                    
                if check == 'O':
                    print("주석 설정창으로")
                    break
                

        else:
            print("종료")
            break
# Out:
# C:\sebin\lab\ecg\save\mit_ann_all\type2\V\100_1906.csv
# C:\sebin\lab\ecg\save\mit_ann_all\type2\V\105_1038.csv
# C:\sebin\lab\ecg\save\mit_ann_all\type2\V\105_1142.csv
# C:\sebin\lab\ecg\save\mit_ann_all\type2\V\105_1201.csv
# C:\sebin\lab\ecg\save\mit_ann_all\type2\V\105_142.csv
# C:\sebin\lab\ecg\save\mit_ann_all\type2\V\105_1432.csv
# C:\sebin\lab\ecg\save\mit_ann_all\type2\V\105_1654.csv
# C:\sebin\lab\ecg\save\mit_ann_all\type2\V\105_1683.csv
# C:\sebin\lab\ecg\save\mit_ann_all\type2\V\105_177.csv
# C:\sebin\lab\ecg\save\mit_ann_all\type2\V\105_1777.csv
# C:\sebin\lab\ecg\save\mit_ann_all\type2\V\105_1807.csv
# C:\sebin\lab\ecg\save\mit_ann_all\type2\V\105_1909.csv
# C:\sebin\lab\ecg\save\mit_ann_all\type2\V\105_1918.csv
# C:\sebin\lab\ecg\save\mit_ann_all\type2\V\105_2070.csv
