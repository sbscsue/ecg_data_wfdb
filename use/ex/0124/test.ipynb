# %%
import numpy as np 
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
import sys
sys.path.append("C:\\sebin\\lab\\ecg2\\git\\ecg_data_wfdb")

# %%
from use.mitbih_ecg.form import ecg_segment

# %%
folder_path = "C:\\sebin\\lab\\ecg2\\data\\original\\01_mitbih"

# %%
ecg = ecg_segment(folder_path+"\\100")
# Out:
# 100

# %%
ecg.record
# Out:
# array([-0.145, -0.145, -0.145, ..., -0.675, -0.765, -1.28 ])

# %%
plt.plot(ecg.record[0:400])

# %%
type(ecg.record[0])
# Out:
# numpy.float64

# %% [markdown]
# float32형으로 변환

# %%
type(ecg.record.astype(np.float32)[0])
# Out:
# numpy.float32

# %%
plt.plot(ecg.record.astype(np.float32)[0:400])

# %%
reEcg = ecg.record.astype(np.float32)

# %%
type(reEcg[0])
# Out:
# numpy.float32

# %%
pdEcg = pd.DataFrame(reEcg,columns=["df"])

# %%
pdEcg.dtypes
# Out:
# df    float32
# dtype: object

# %%
pdEcg
# Out:
#            df
# 0      -0.145
# 1      -0.145
# 2      -0.145
# 3      -0.145
# 4      -0.145
# ...       ...
# 649995 -0.075
# 649996 -0.445
# 649997 -0.675
# 649998 -0.765
# 649999 -1.280
#
# [650000 rows x 1 columns]

# %%
pdEcg.dtypes
# Out:
# df    float32
# dtype: object

# %%
pdEcg.to_csv("./happy2.csv",header=False,index=False,float_format = '%.3f')

# %% [markdown]
# # X

# %% [markdown]
# bytes형식으로 변환

# %%
byteEcg = reEcg.tobytes()

# %%
type(byteEcg)
# Out:
# bytes

# %%
len(byteEcg)
# Out:
# 2600000

# %%
byteEcg[0]
# Out:
# 225

# %%
import struct

# %% [markdown]
# 3째 자리에서 반올림

# %%
struct.unpack('f',byteEcg[80:84])
# Out:
# (-0.17499999701976776,)

# %%
ecg.record[0]
# Out:
# -0.145

# %%
ecg.record[20]
# Out:
# -0.175

# %%
reEcg[20]
# Out:
# -0.175
