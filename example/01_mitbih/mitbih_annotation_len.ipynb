# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import os 

home_path = "C:\\sebin\\lab\\ecg2\\git"
git_path = home_path+"\\ecg_data_wfdb"

sys.path.append(git_path)

from use.mitbih_ecg.form import ecg_segment

# %%
data_path = "C:\\sebin\\lab\\ecg\\data_tosegment\\mitbih_ann"

# %%
folders = os.listdir(data_path)

# %%
with open("len.txt",mode='wt',encoding='utf-8') as f:
    for name in folders:
        path = data_path+"\\"+name+"\\"+"csv"
        print(path)
        
        ann_len = {}
        files = os.listdir(path)
        for csv in files:
            ann = csv.split("_")[0]
            if ann not in ann_len:
                ann_len[ann] = 0
                print(ann_len.keys)
            ann_len[ann] = ann_len[ann]+1
        f.write(str(name)+"\t\t"+str(ann_len)+"\n")
# Out:
# C:\sebin\lab\ecg\data_tosegment\mitbih_ann\100\csv
# <built-in method keys of dict object at 0x000002152F51AD40>
# <built-in method keys of dict object at 0x000002152F51AD40>
# <built-in method keys of dict object at 0x000002152F51AD40>
# C:\sebin\lab\ecg\data_tosegment\mitbih_ann\101\csv
# <built-in method keys of dict object at 0x000002152F674E80>
# <built-in method keys of dict object at 0x000002152F674E80>
# <built-in method keys of dict object at 0x000002152F674E80>
# C:\sebin\lab\ecg\data_tosegment\mitbih_ann\103\csv
# <built-in method keys of dict object at 0x000002152F509400>
# <built-in method keys of dict object at 0x000002152F509400>
# C:\sebin\lab\ecg\data_tosegment\mitbih_ann\105\csv
# <built-in method keys of dict object at 0x000002152F51AD40>
# <built-in method keys of dict object at 0x000002152F51AD40>
# <built-in method keys of dict object at 0x000002152F51AD40>
# C:\sebin\lab\ecg\data_tosegment\mitbih_ann\106\csv
# ...
