# %%
import pandas as pd
import matplotlib.pyplot as plt
from os import listdir

# %%
path = "C:/sebin/211012_1511"

# %%
d = listdir(path)

# %%
d
# Out:
# ['1.csv',
#  '10.csv',
#  '11.csv',
#  '12.csv',
#  '13.csv',
#  '2.csv',
#  '3.csv',
#  '4.csv',
#  '5.csv',
#  '6.csv',
#  '7.csv',
#  '8.csv',
#  '9.csv']

# %%
name = []

# %%
for i in d:
    if (i.endswith(".csv")):
        name.append(i)

# %%
name
# Out:
# ['1.csv',
#  '10.csv',
#  '11.csv',
#  '12.csv',
#  '13.csv',
#  '2.csv',
#  '3.csv',
#  '4.csv',
#  '5.csv',
#  '6.csv',
#  '7.csv',
#  '8.csv',
#  '9.csv']

# %% [markdown]
# # 1. 총 합
# -----------------

# %%
for i in name:
   plt.plot(pd.read_csv(path+"/"+i))

# %% [markdown]
# # 2. 하나씩
# -----------------

# %%
plt.plot(pd.read_csv(path+"/"+'1.csv'))

# %%
plt.plot(pd.read_csv(path+"/"+'2.csv'))

# %%
plt.plot(pd.read_csv(path+"/"+'3.csv'))

# %%
plt.plot(pd.read_csv(path+"/"+'4.csv'))

# %%
plt.plot(pd.read_csv(path+"/"+'5.csv'))

# %%
plt.plot(pd.read_csv(path+"/"+'6.csv'))

# %%
plt.plot(pd.read_csv(path+"/"+'7.csv'))

# %%
plt.plot(pd.read_csv(path+"/"+'8.csv'))

# %%
plt.plot(pd.read_csv(path+"/"+'9.csv'))

# %%
plt.plot(pd.read_csv(path+"/"+'10.csv'))

# %%
plt.plot(pd.read_csv(path+"/"+'11.csv'))

# %%
plt.plot(pd.read_csv(path+"/"+'12.csv'))

# %%
plt.plot(pd.read_csv(path+"/"+'13.csv'))
