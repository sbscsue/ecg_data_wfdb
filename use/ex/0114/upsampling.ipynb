# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 

from scipy import signal

# %%
import sys
sys.path.append("C:\\sebin\\lab\\ecg2\\git\\ecg_data_wfdb")

# %%
from use.mitbih_ecg.form import ecg_segment

# %%
folder_path = "C:\\sebin\\lab\\ecg2\\data\\original\\01_mitbih"

# %%
path = folder_path+"\\"+"105"

# %% [markdown]
# # 1. resmaple check

# %% [markdown]
# -------------------

# %%
ecg = [ecg_segment(path,ver="nsv",mode =1 ,seg_size=144) ,ecg_segment(path,ver="nsv",mode = 1,seg_size=144,resample_seg_size =8000 )]
# Out:
# 105
# 105

# %%
ecg[0].annotation.symbol
# Out:
# ['+',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'V',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'V',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'V',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'V',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'V',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  '~',
#  'N',
#  'N',
#  '~',
#  'N',
#  'N',
# ...

# %%
ecg[0].beat
# Out:
# array([['197', 'N', '1.18'],
#        ['459', 'N', '1.175'],
#        ['708', 'N', '1.155'],
#        ...,
#        ['649221', 'N', '1.115'],
#        ['649471', 'N', '1.145'],
#        ['649740', 'N', '1.14']], dtype='<U32')

# %%
ecg[0].seg
# Out:
# [{'record': array([-0.31 , -0.315, -0.295, -0.3  , -0.31 , -0.315, -0.315, -0.32 ,
#          -0.315, -0.305, -0.31 , -0.33 , -0.325, -0.33 , -0.32 , -0.32 ,
#          -0.31 , -0.325, -0.33 , -0.33 , -0.325, -0.325, -0.335, -0.335,
#          -0.33 , -0.32 , -0.32 , -0.335, -0.335, -0.345, -0.34 , -0.325,
#          -0.32 , -0.325, -0.35 , -0.36 , -0.35 , -0.325, -0.31 , -0.325,
#          -0.335, -0.34 , -0.34 , -0.33 , -0.325, -0.335, -0.34 , -0.345,
#          -0.33 , -0.335, -0.325, -0.325, -0.335, -0.34 , -0.325, -0.325,
#          -0.32 , -0.325, -0.33 , -0.345, -0.325, -0.325, -0.325, -0.32 ,
#          -0.325, -0.33 , -0.335, -0.305, -0.31 , -0.295, -0.285, -0.29 ,
#          -0.245, -0.23 , -0.21 , -0.23 , -0.245, -0.245, -0.225, -0.19 ,
#          -0.155, -0.145, -0.15 , -0.155, -0.15 , -0.14 , -0.13 , -0.12 ,
#          -0.125, -0.14 , -0.145, -0.15 , -0.155, -0.15 , -0.175, -0.2  ,
#          -0.24 , -0.28 , -0.325, -0.36 , -0.38 , -0.39 , -0.38 , -0.38 ,
# ...

# %%
ecg[1].seg
# Out:
# [{'record': array([-0.31      , -0.3089705 , -0.30808468, ..., -0.31392693,
#          -0.312482  , -0.31117153]),
#   'annotation': 'N'},
#  {'record': array([-0.28      , -0.27900263, -0.27822699, ..., -0.28428328,
#          -0.28264599, -0.28121606]),
#   'annotation': 'N'},
#  {'record': array([-0.255     , -0.2529606 , -0.25105935, ..., -0.26187077,
#          -0.2594636 , -0.25717037]),
#   'annotation': 'N'},
#  {'record': array([-0.27      , -0.26960295, -0.26919039, ..., -0.2711077 ,
#          -0.27075126, -0.27038242]),
#   'annotation': 'N'},
#  {'record': array([-0.235     , -0.23377722, -0.23268563, ..., -0.23941721,
#          -0.23782479, -0.23635063]),
#   'annotation': 'N'},
#  {'record': array([-0.25      , -0.24853063, -0.24717654, ..., -0.25503189,
#          -0.25325825, -0.25157828]),
#   'annotation': 'N'},
#  {'record': array([-0.245     , -0.24435267, -0.24381517, ..., -0.24757899,
#          -0.24661606, -0.24575531]),
#   'annotation': 'N'},
# ...

# %%
len(ecg[1].seg[0]['annotation'])
# Out:
# 1

# %%
ann = []
for i in range(len(ecg[0].seg)):
    ann.append(ecg[0].seg[i]['annotation'])

# %%
len(ann)
# Out:
# 2567

# %%
len(ecg[0].seg)
# Out:
# 2567

# %%
len(ecg[0].beat)
# Out:
# 2567

# %%
len(ecg[0].non_beat)
# Out:
# 119

# %%
len(ecg[1].seg)
# Out:
# 2567

# %%
len(ecg[1].beat)
# Out:
# 2567

# %%
ann.count('N')
# Out:
# 2526

# %%
ann.count('S')
# Out:
# 0

# %%
ann.count('V')
# Out:
# 41

# %%
index = 30

# %%
plt.plot(ecg[0].seg[index]['record'])

# %%
plt.plot(ecg[1].seg[index]['record'])

# %% [markdown]
# # 2. 개수 check
# -------------------------

# %%
path = folder_path+"\\"+"102"

# %%
ecg = [ecg_segment(path,ver="mitbih",mode =1 ,seg_size=144) ,ecg_segment(path,ver="aami",mode = 1,seg_size=144),ecg_segment(path,ver="nsv",mode = 1,seg_size=144)]
# Out:
# 102
# 102
# 102

# %%
for i in ecg:
    ann = []
    for j in range(len(i.seg)):
        ann.append(i.seg[j]['annotation'])
    print(len(ann))
    print("---------------------")
# Out:
# 2186
# ---------------------
# 2186
# ---------------------
# 103
# ---------------------
