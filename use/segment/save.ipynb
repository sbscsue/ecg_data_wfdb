# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
import time

# %%
import sys
sys.path.append("C:\\sebin\\lab\\ecg2\\git\\ecg_data_wfdb")

# %%
from use.mitbih_ecg.form import ecg_segment

# %% [markdown]
# ## ecg output_all

# %%
path = "C:\\sebin\\lab\\ecg2\\data\\original\\01_mitbih"

# %%
files =[
    [100,[0]],
    [101,[0]],
    [103,[0]],
    [105,[0]],
    [106,[0]],
    [107,[0]],
    [108,[0]],
    [109,[0]],
    [111,[0]],
    [112,[0]],
    [113,[0]],
    [114,[1]],
    [115,[0]],
    [116,[0]],
    [117,[0]],
    [118,[0]],
    [119,[0]],
    [121,[0]],
    [122,[0]],
    [123,[0]],
    [124,[0]],
    [200,[0]],
    [201,[0]],
    [202,[0]],
    [203,[0]],
    [205,[0]],
    [207,[0]],
    [208,[0]],
    [209,[0]],
    [210,[0]],
    [212,[0]],
    [213,[0]],
    [214,[0]],
    [215,[0]],
    [217,[0]],
    [219,[0]],
    [220,[0]],
    [221,[0]],
    [222,[0]],
    [223,[0]],
    [228,[0]],
    [230,[0]],
    [231,[0]],
    [232,[0]],
    [233,[0]],
    [234,[0]],
]

# %%
dfsdfa df
# Out:
#   File "C:\Users\kyj\AppData\Local\Temp/ipykernel_20444/2025404379.py", line 1
#     dfsdfa df
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# # SEGMENT

# %%
for i in files:
    ecg = ecg_segment(path+"\\"+str(i[0]),channel=i[1],ver="nsv", mode = 2, seg_size = 160)
    ecg.output_segment("C:\\sebin\\lab\\ecg2\\data\\segment\\06_nsv_lead2_160_baselineRemove",img=False)
# Out:
# 100
# baseline remove
# output
# 101
# baseline remove
# output
# 103
# baseline remove
# output
# 105
# baseline remove
# output
# 106
# baseline remove
# output
# 107
# baseline remove
# output
# 108
# baseline remove
# output
# 109
# baseline remove
# output
# 111
# baseline remove
# output
# 112
# baseline remove
# output
# 113
# baseline remove
# output
# 114
# baseline remove
# output
# 115
# baseline remove
# output
# 116
# baseline remove
# output
# 117
# baseline remove
# output
# 118
# baseline remove
# output
# 119
# baseline remove
# output
# 121
# baseline remove
# output
# 122
# baseline remove
# output
# 123
# baseline remove
# output
# 124
# baseline remove
# output
# 200
# baseline remove
# output
# 201
# baseline remove
# output
# 202
# baseline remove
# output
# 203
# baseline remove
# output
# 205
# baseline remove
# output
# 207
# baseline remove
# output
# 208
# baseline remove
# output
# 209
# baseline remove
# output
# 210
# baseline remove
# output
# 212
# ...

# %% [markdown]
# # ALL

# %%
for i in files:
    ecg = ecg_segment(path+"\\"+str(i[0]),channel=i[1])
    ecg.returnAllReSampleEcgToString("C:\\sebin\\lab\\ecg2\\data\\all_mitbih\\02)360fs_original")
# Out:
# 100
# 0        -0.145000
# 1        -0.100122
# 2        -0.201514
# 3        -0.086922
# 4        -0.199469
#             ...
# 719995   -0.201893
# 719996   -0.638596
# 719997   -0.605683
# 719998   -0.924384
# 719999   -1.224905
# Name: 0, Length: 720000, dtype: float64
# 101
# 0        -0.345000
# 1        -0.360982
# 2        -0.324629
# 3        -0.366066
# 4        -0.325120
#             ...
# 719995   -0.321392
# 719996   -0.259674
# 719997   -0.339928
# 719998   -0.219936
# 719999   -0.008962
# Name: 0, Length: 720000, dtype: float64
# 103
# 0        -0.375000
# 1        -0.390752
# 2        -0.355325
# 3        -0.394964
# 4        -0.356556
#             ...
# 719995   -0.245185
# 719996   -0.192510
# 719997   -0.283681
# 719998   -0.180635
# 719999   -0.014061
# Name: 0, Length: 720000, dtype: float64
# 105
# 0        -0.445000
# 1        -0.507303
# 2        -0.367465
# 3        -0.524154
# 4        -0.371026
#             ...
# 719995    0.226699
# 719996    0.589929
# ...
