# %%
import numpy as np 
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
from scipy.signal.signaltools import resample

# %%
import sys
sys.path.append("C:\\sebin\\lab\\ecg2\\git\\ecg_data_wfdb")

# %%
from use.mitbih_ecg.form import ecg_segment

# %%
folder_path = "C:\\sebin\\lab\\ecg2\\data\\original\\01_mitbih"

# %% [markdown]
# # function make

# %%
ecg = ecg_segment(folder_path+"\\100")
# Out:
# 100

# %%
ecg.record
# Out:
# array([-0.145, -0.145, -0.145, ..., -0.675, -0.765, -1.28 ])

# %%
plt.plot(ecg.record[0:360])

# %%
type(ecg.record[0])
# Out:
# numpy.float64

# %% [markdown]
# float32형으로 변환

# %%
reEcg = ecg.record.astype(np.float32)

# %% [markdown]
# resample

# %%
reSampleEcg = resample(reEcg,30*60*400)

# %%
reSampleEcg
# Out:
# array([-0.14499994, -0.10012147, -0.20151393, ..., -0.60568285,
#        -0.9243844 , -1.224905  ], dtype=float32)

# %%
plt.plot(reSampleEcg[0:400])

# %%
type(reSampleEcg[0])
# Out:
# numpy.float32

# %%
pdEcg = pd.DataFrame(reSampleEcg,columns=["df"])

# %%
pdEcg.dtypes
# Out:
# df    float32
# dtype: object

# %%
pdEcg
# Out:
#               df
# 0      -0.145000
# 1      -0.100121
# 2      -0.201514
# 3      -0.086922
# 4      -0.199469
# ...          ...
# 719995 -0.201893
# 719996 -0.638596
# 719997 -0.605683
# 719998 -0.924384
# 719999 -1.224905
#
# [720000 rows x 1 columns]

# %%
pdEcg.dtypes
# Out:
# df    float32
# dtype: object

# %%
pdEcg.to_csv("./happy2.csv",header=False,index=False)

# %% [markdown]
# # test

# %% [markdown]
# # X

# %% [markdown]
# bytes형식으로 변환

# %%
byteEcg = reEcg.tobytes()

# %%
type(byteEcg)
# Out:
# bytes

# %%
len(byteEcg)
# Out:
# 2600000

# %%
byteEcg[0]
# Out:
# 225

# %%
import struct

# %% [markdown]
# 3째 자리에서 반올림

# %%
struct.unpack('f',byteEcg[80:84])
# Out:
# (-0.17499999701976776,)

# %%
ecg.record[0]
# Out:
# -0.145

# %%
ecg.record[20]
# Out:
# -0.175

# %%
reEcg[20]
# Out:
# -0.175
