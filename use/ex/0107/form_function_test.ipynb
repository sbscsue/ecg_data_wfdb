# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("C:\\sebin\\lab\\ecg2\\git\\ecg_data_wfdb")

# %%
from use.mitbih_ecg.form import ecg_segment

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import os

# %% [markdown]
# -----------------------

# %% [markdown]
# # 1. downsampling function check

# %%
folder_path = "C:\\sebin\\lab\\ecg2\\data\\original\\01_mitbih"

# %%
path = folder_path+"\\"+"115"

# %%
ecg = [ecg_segment(path,ver="binary",mode =1 ,seg_size=144,resample_seg_size = -1) ,ecg_segment(path,ver="binary",mode = 1,seg_size=144,resample_seg_size = 300)]
# Out:
# 100
# 100

# %%
plt.subplot(2,1,1)
plt.plot(ecg[0].seg[0]['record'])
plt.subplot(2,1,2)
plt.plot(ecg[1].seg[0]['record'])

# %%
print("original: {} \t sampling: {}".format(ecg[0].seg[0]['record'].size,ecg[1].seg[0]['record'].size))
# Out:
# original: 288 	 sampling: 300

# %%
def check(num):
    plt.subplot(2,1,1)
    plt.plot(ecg[0].seg[num]['record'])
    plt.subplot(2,1,2)
    plt.plot(ecg[1].seg[num]['record'])

    print("original: {} \t sampling: {}".format(ecg[0].seg[num]['record'].size,ecg[1].seg[num]['record'].size))

# %%
for i in range(len(ecg[0].seg)):
    check(i)
# Out:
# original: 288 	 sampling: 300
# original: 288 	 sampling: 300
# original: 288 	 sampling: 300
# original: 288 	 sampling: 300
# original: 288 	 sampling: 300
# original: 288 	 sampling: 300
# original: 288 	 sampling: 300
# original: 288 	 sampling: 300
# original: 288 	 sampling: 300
# original: 288 	 sampling: 300
# original: 288 	 sampling: 300
# original: 288 	 sampling: 300
# original: 288 	 sampling: 300
# original: 288 	 sampling: 300
# original: 288 	 sampling: 300
# original: 288 	 sampling: 300
# original: 288 	 sampling: 300
# original: 288 	 sampling: 300
# original: 288 	 sampling: 300
# original: 288 	 sampling: 300
# original: 288 	 sampling: 300
# original: 288 	 sampling: 300
# original: 288 	 sampling: 300
# original: 288 	 sampling: 300
# original: 288 	 sampling: 300
# original: 288 	 sampling: 300
# original: 288 	 sampling: 300
# original: 288 	 sampling: 300
# original: 288 	 sampling: 300
# original: 288 	 sampling: 300
# original: 288 	 sampling: 300
# ...

# %%
data = pd.read_csv("C:\\sebin\\lab\\ecg2\\git\\ecg_data_wfdb\\use\\ex\\0107\\annotation\\normal\\csv\\100_0.csv")

# %%
data.size
# Out:
# 301

# %%
ecg = [ecg_segment(path,ver="binary",mode =1 ,seg_size=144,resample_seg_size = -1) ,ecg_segment(path,ver="binary",mode = 2,seg_size=144,resample_seg_size = -1)]
# Out:
# 115
# 115
# baseline remove

# %%
plt.plot(ecg[0].record,color = "blue")
plt.plot(ecg[1].record,color="red")
plt.xlim([10*360,30*360])
# Out:
# (3600.0, 10800.0)

# %%
from BaselineRemoval import BaselineRemoval

# %%
input_array = ecg[0].record

# %%
baseObj=BaselineRemoval(input_array)

# %%
Zhangfit_output=baseObj.ZhangFit()

# %%
input_array
# Out:
# array([-0.2 , -0.2 , -0.2 , ...,  0.34,  0.34,  0.  ])

# %%
Zhangfit_output
# Out:
# array([0.27004981, 0.27275031, 0.27545081, ..., 0.74859458, 0.74458875,
#        0.40058292])

# %%
plt.plot(input_array[0:360*30])

# %%
plt.plot(input_array,color="red")
plt.plot(input_array,color="blue")
plt.xlim([8000,10000])
# Out:
# (8000.0, 10000.0)

# %%
plt.plot(ecg[0].record)
plt.xlim([0,1000])
# Out:
# (0.0, 1000.0)

# %%
plt.plot(ecg[1].record)
plt.xlim([0,1000])
# Out:
# (0.0, 1000.0)
