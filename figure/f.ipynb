# %%
import sys
sys.path.append("C:\\sebin\\lab\\ecg2\\git\\ecg_data_wfdb")

from use.mitbih_ecg.form import ecg_segment 
from use.segment.open import toDataframe_interval,all_check
from use.tensor.input import to_mixmax_tensor

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 

import seaborn as sns
from seaborn import heatmap

# %%
path = "C:\\sebin\\lab\\ecg2\\data\\original\\01_mitbih"

# %% [markdown]
# # 1번 figure

# %%
ecg = ecg_segment(path+"\\"+"208",channel=[0],ver="aami",baseLineRemoveFlag = 1, intervalN = 10,leftSegSize=360,rightSegSize=180, resample_seg_size=-1)
# Out:
# 208
# tmp:  3040
# startIndex,endIndex:  2   2953
# seg:  2952
# interval:  2952
# startIndex:  8
# seg,interval:  2944   2944

# %%
ecg.beat[4]
# Out:
# array(['853', 'V', '1.185'], dtype='<U32')

# %%
record = ecg.record

# %%
beat = ecg.beat[4]

# %%
record
# Out:
# array([-0.105, -0.105, -0.105, ..., -0.17 , -0.16 ,  0.   ])

# %%
beat
# Out:
# array(['853', 'V', '1.185'], dtype='<U32')

# %%
rPeakIndex = int(beat[0])

plt.plot(record[rPeakIndex-144:rPeakIndex+144],color="#d62728")

plt.title("Ventricular ectopic beat beat")
plt.xlabel("Sample")
plt.ylabel("Amplitude")


plt.savefig("figure01_03")

# %%
ecg = ecg_segment(path+"\\"+"100",channel=[0],ver="aami",baseLineRemoveFlag = 1, intervalN = 10,leftSegSize=360,rightSegSize=180, resample_seg_size=-1)
# Out:
# 100
# tmp:  2274
# startIndex,endIndex:  1   2271
# seg:  2271
# interval:  2271
# startIndex:  9
# seg,interval:  2262   2262

# %%
ecg.beat[4]
# Out:
# array(['1231', 'N', '0.82'], dtype='<U32')

# %%
record = ecg.record

# %%
beat = ecg.beat[4]

# %%
record
# Out:
# array([-0.145, -0.145, -0.145, ..., -0.675, -0.765, -1.28 ])

# %%
beat
# Out:
# array(['1231', 'N', '0.82'], dtype='<U32')

# %%
rPeakIndex = int(beat[0])

plt.plot(record[rPeakIndex-144:rPeakIndex+144],color="#d62728")

plt.title(" beat")
plt.xlabel("Sample")
plt.ylabel("Amplitude")


plt.savefig("figure01_01")

# %%
ecg = ecg_segment(path+"\\"+"222",channel=[0],ver="aami",baseLineRemoveFlag = 1, intervalN = 10,leftSegSize=360,rightSegSize=180, resample_seg_size=-1)
# Out:
# 222
# tmp:  2634
# startIndex,endIndex:  1   2481
# seg:  2481
# interval:  2481
# startIndex:  9
# seg,interval:  2472   2472

# %%
for i in range(len(ecg.beat)):
    if(ecg.beat[i][1]=="S"):
        print(i)
# Out:
# 652
# 657
# 659
# 661
# 663
# 685
# 695
# 697
# 753
# 755
# 759
# 762
# 764
# 766
# 768
# 770
# 837
# 839
# 841
# 843
# 845
# 847
# 849
# 851
# 853
# 856
# 859
# 862
# 864
# 889
# 891
# 893
# 894
# 895
# 897
# 899
# 935
# 940
# 944
# 946
# 947
# 949
# 968
# 970
# 973
# 1003
# 1005
# 1008
# 1010
# 1013
# 1047
# 1062
# 1064
# 1069
# 1091
# 1093
# 1094
# 1096
# 1097
# 1098
# 1100
# 1111
# 1113
# 1114
# 1116
# 1134
# 1151
# 1153
# 1156
# 1174
# 1177
# 1219
# 1238
# 1421
# 1424
# 1426
# 1428
# 1433
# 1472
# 1474
# 1479
# 1485
# 1487
# 1503
# 1507
# 1512
# 1514
# 1516
# 1518
# 1520
# 1522
# 1524
# 1526
# 1528
# 1530
# 1532
# 1534
# 1536
# 1538
# 1540
# 1544
# 1545
# 1547
# 1549
# 1551
# 1553
# 1555
# 1557
# 1559
# 1561
# 1563
# 1564
# 1566
# 1568
# 1570
# 1572
# 1574
# 1576
# 1578
# 1579
# 1581
# 1583
# 1585
# 1587
# 1589
# 1591
# 1593
# 1595
# 1597
# 1599
# 1601
# 1621
# 1623
# 1624
# 1626
# 1627
# 1629
# 1643
# 1644
# 1646
# 1649
# 1650
# 1652
# 1673
# 1675
# 1676
# 1677
# 1697
# 1698
# ...

# %%
record = ecg.record

# %%
beat = ecg.beat[657]

# %%
record
# Out:
# array([-0.14, -0.14, -0.14, ..., -0.27, -0.28,  0.  ])

# %%
beat
# Out:
# array(['193737', 'S', '0.88'], dtype='<U32')

# %%
rPeakIndex = int(beat[0])

plt.plot(record[rPeakIndex-144:rPeakIndex+144],color="#d62728")

plt.title("Supraventricular ectopic beat")
plt.xlabel("Sample")
plt.ylabel("Amplitude")


plt.savefig("figure01_02")

# %% [markdown]
# # 2번 figure

# %%
ecg = ecg_segment(path+"\\"+"100",channel=[0],ver="aami",baseLineRemoveFlag = 1, intervalN = 10,leftSegSize=360,rightSegSize=180, resample_seg_size=-1)
# Out:
# 100
# tmp:  2274
# startIndex,endIndex:  1   2271
# seg:  2271
# interval:  2271
# startIndex:  9
# seg,interval:  2262   2262

# %%
plt.plot(ecg.record[0:360*4],color = "red")
plt.savefig("figure02_01.jpg")

# %%
plt.plot(ecg.seg[4]['record'],color="red")

plt.savefig("figure02_02.jpg")

# %%
plt.plot(ecg.seg[4]['record'])
plt.plot(ecg.record[int(ecg.beat[4][0])-360:int(ecg.beat[4][0])+180],color="red")

# %%
ecg.seg[2]
# Out:
# {'record': array([-0.31 , -0.315, -0.315, -0.31 , -0.295, -0.3  , -0.295, -0.315,
#         -0.31 , -0.29 , -0.265, -0.24 , -0.255, -0.24 , -0.25 , -0.225,
#         -0.225, -0.215, -0.21 , -0.2  , -0.195, -0.195, -0.18 , -0.175,
#         -0.18 , -0.205, -0.215, -0.21 , -0.21 , -0.21 , -0.21 , -0.215,
#         -0.225, -0.21 , -0.18 , -0.17 , -0.185, -0.24 , -0.255, -0.255,
#         -0.27 , -0.275, -0.285, -0.3  , -0.3  , -0.315, -0.305, -0.3  ,
#         -0.295, -0.3  , -0.315, -0.31 , -0.31 , -0.3  , -0.3  , -0.305,
#         -0.315, -0.325, -0.32 , -0.32 , -0.32 , -0.325, -0.34 , -0.335,
#         -0.325, -0.315, -0.32 , -0.345, -0.37 , -0.395, -0.425, -0.445,
#         -0.465, -0.51 , -0.53 , -0.485, -0.37 , -0.235, -0.09 ,  0.105,
#          0.375,  0.655,  0.82 ,  0.865,  0.735,  0.45 ,  0.06 , -0.27 ,
#         -0.43 , -0.46 , -0.415, -0.385, -0.365, -0.355, -0.355, -0.345,
#         -0.35 , -0.35 , -0.36 , -0.345, -0.34 , -0.34 , -0.335, -0.335,
# ...

# %%
ecg.beat[2]
# Out:
# array(['662', 'N', '0.885'], dtype='<U32')

# %%
ecg.annotation.symbol
# Out:
# ['+',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'A',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
# ...

# %%
ecg.beat[4]
# Out:
# array(['1231', 'N', '0.82'], dtype='<U32')
